# %%
run combinatorics.py
# Out:
# Seen agents:
# {'Kayla': 8.0, 'Anna': 2.0, 'Amber': 2.0, 'Alexis': 4.0, 'Brianna': 7.0, 'Victoria': 2.0}
# Possible sums:
# [6.0, 8.0, 8.0, 8.0, 11.0, 11.0, 11.0, 12.0, 12.0, 12.0, 13.0, 13.0, 13.0, 14.0, 14.0, 14.0, 17.0, 17.0, 17.0, 19.0]
# Picked agents:
# {'Anna': 2.0, 'Alexis': 4.0, 'Brianna': 7.0}
# Picked sum:
# 13.0
# Ranking:
# 10
# Seen agents:
# {'Mary': 3.0, 'Anna': 3.0, 'Kimberly': 1.0, 'Alexis': 4.0, 'Brianna': 7.0, 'Megan': 7.0}
# Possible sums:
# [7.0, 8.0, 8.0, 10.0, 11.0, 11.0, 11.0, 11.0, 12.0, 12.0, 13.0, 13.0, 14.0, 14.0, 14.0, 14.0, 15.0, 17.0, 17.0, 18.0]
# Picked agents:
# {'Mary': 3.0, 'Kimberly': 1.0, 'Brianna': 7.0}
# Picked sum:
# 11.0
# Ranking:
# 4
# Seen agents:
# {'Mary': 3.0, 'Christina': 3.0, 'Kimberly': 1.0, 'Abigail': 4.0, 'Brianna': 7.0, 'Morgan': 3.0}
# Possible sums:
# [7.0, 7.0, 7.0, 8.0, 8.0, 8.0, 9.0, 10.0, 10.0, 10.0, 11.0, 11.0, 11.0, 12.0, 13.0, 13.0, 13.0, 14.0, 14.0, 14.0]
# Picked agents:
# ...
